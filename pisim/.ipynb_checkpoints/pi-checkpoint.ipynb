# %%
from random import uniform
from itertools import groupby

repetition_factor = 5
num_pi_calc = 3
final_values = []

def pi_estimate(n):
    var = 0
    for i in range(n):
        x = uniform(-1, 1)
        y = uniform(-1, 1)
        if (x * x) + (y * y) <= 1:
            var += 1
    probability = var / n
    pi_estimate = 4 * probability
    final_value = pi_estimate
    return final_value

results = []

for i in range(num_pi_calc):
    n = 1
    batch = 0
    for _ in range(repetition_factor):
        final_value = pi_estimate(n)
        results.append((final_value, n))
        print(">>>>> Batch",batch ,"Sample Count", n)
        n *= 10
        batch += 1

results.sort(key=lambda x: x[1])

final_values = [result[0] for result in results]
# thank you Stack Overflow <3

master_list = []
for i in range(repetition_factor):
    split_list = final_values[0+i*num_pi_calc:num_pi_calc+i*num_pi_calc]
    master_list.append(split_list)
# Out:
# >>>>> Batch 0 Sample Count 1
# >>>>> Batch 1 Sample Count 10
# >>>>> Batch 2 Sample Count 100
# >>>>> Batch 3 Sample Count 1000
# >>>>> Batch 4 Sample Count 10000
# >>>>> Batch 0 Sample Count 1
# >>>>> Batch 1 Sample Count 10
# >>>>> Batch 2 Sample Count 100
# >>>>> Batch 3 Sample Count 1000
# >>>>> Batch 4 Sample Count 10000
# >>>>> Batch 0 Sample Count 1
# >>>>> Batch 1 Sample Count 10
# >>>>> Batch 2 Sample Count 100
# >>>>> Batch 3 Sample Count 1000
# >>>>> Batch 4 Sample Count 10000

# %%
import statistics
for split_list in master_list:
    std_deviation = statistics.stdev(split_list)
    print(split_list, ":", std_deviation)
# Out:
# [4.0, 0.0, 4.0] : 2.309401076758503
# [2.4, 3.2, 3.6] : 0.6110100926607788
# [3.24, 3.2, 3.4] : 0.10583005244258346
# [3.144, 3.124, 3.064] : 0.04163331998932269
# [3.1868, 3.1184, 3.1668] : 0.03516892567783858

# %%
import matplotlib.pyplot as plt

std_master_list = []
x_axis = []
xa = 0
for split_list in master_list:
    std_deviation = statistics.stdev(split_list)
    std_master_list.append(std_deviation)
    x_axis.append(xa)
    xa += 1
    
plt.title("Error v. Number of Samples")
plt.xlabel("# Samples")
plt.ylabel("Error")
plt.plot(x_axis, std_master_list)
plt.show()
